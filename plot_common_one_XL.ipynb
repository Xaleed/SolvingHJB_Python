# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#XLXLXL = pd.read_csv('XLXLXL_20_0.05_copy1.csv')
XL = pd.read_csv('oneXL_20_0.02_copy2.csv')
#XLXLXL = pd.read_csv('XLXLXL_15_0.01_copy2.csv')
XLXLXL_edit = pd.read_csv('XLXLXL_15_0.02_copy2_edit.csv')
#XL1 = pd.read_csv('oneXL_20_0.01_copy2.csv')
XL_oneXLcommon = pd.read_csv('oneXLcommon_20_0.01.csv')
P_onePcommon = pd.read_csv('onePcommon_30_0.01.csv')
XL_twoXLcommon= pd.read_csv('twoXLcommon_20_0.01.csv')
P_twoPcommon = pd.read_csv('twoPcommon_30_0.01.csv')
#XLXLXL1= pd.read_csv('XLXLXL_2400_6.csv')
#XLXLp= pd.read_csv('XLXLp.csv')
#XLpXL= pd.read_csv('XLpXL.csv')
#pXLXL= pd.read_csv('pXLXL_600_20.csv')
#pXLp= pd.read_csv('pXLp.csv')
P = pd.read_csv('onep_20_0.02.csv')
ppp= pd.read_csv('ppp_20_0.02.csv')
#ppXL= pd.read_csv('ppXL.csv')
#XLpp= pd.read_csv('XLpp.csv')

# %%
XLXLXL_edit.head()
# Out:
#    Unnamed: 0     x  V_XLXLXL  XLXLXL_Line1  XLXLXL_Line2  XLXLXL_Line3
# 0           0  0.00  5.167858     19.983224     10.760178     19.051327
# 1           1  0.02  5.214851     19.977408      6.895459     18.824729
# 2           2  0.04  5.260809     19.987118      0.030478     18.803752
# 3           3  0.06  5.282517     19.994366      0.066391     17.031528
# 4           4  0.08  5.317194     19.983417      0.073780      0.082211

# %%
plt.figure(figsize=(12,6))
plt.plot(XLXLXL_edit.x, XLXLXL_edit.XLXLXL_Line1,label='$M_1$')
plt.plot(XLXLXL_edit.x, XLXLXL_edit.XLXLXL_Line2,label='$M_2$')
plt.plot(XLXLXL_edit.x, XLXLXL_edit.XLXLXL_Line3,label='$M_3$')
plt.xlim(0,10)
plt.ylim(0,8)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multipleXLRE_thinning", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(XL.x, XL.XLXLXL_Line1,label='$M$', linestyle='-')
plt.xlabel('$x$', fontsize=20)
plt.xlim(0,10)
plt.ylim(0,8)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./oneXLRE_thinning", bbox_inches='tight')
plt.show()

# %%
ppp.head()
# Out:
#    Unnamed: 0     x     V_ppp  ppp_Line1  ppp_Line2  ppp_Line3
# 0           0  0.00  4.650216        1.0   1.000000   1.000000
# 1           1  0.02  4.690488        1.0   0.010000   0.010000
# 2           2  0.04  4.708620        1.0   0.014171   0.010000
# 3           3  0.06  4.726144        1.0   0.021803   0.014551
# 4           4  0.08  4.743570        1.0   0.029423   0.019629

# %%
plt.figure(figsize=(12,6))
plt.plot(ppp.x, ppp.ppp_Line1,label='$b_1$', linestyle='-')
plt.plot(ppp.x, ppp.ppp_Line2,label='$b_2$', linestyle='dashdot')
plt.plot(ppp.x, ppp.ppp_Line3,label='$b_3$')
plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multiplePRE_thinning", bbox_inches='tight')
plt.show()

# %%
P.head()
# Out:
#    Unnamed: 0     x     V_ppp  ppp_Line1  ppp_Line2  ppp_Line3
# 0           0  0.00  4.237407   1.000000        0.0        0.0
# 1           1  0.02  4.272328   0.999995        0.0        0.0
# 2           2  0.04  4.306399   1.000000        0.0        0.0
# 3           3  0.06  4.339655   1.000000        0.0        0.0
# 4           4  0.08  4.372130   1.000000        0.0        0.0

# %%
plt.figure(figsize=(12,6))
plt.plot(ppp.x, ppp.ppp_Line1,label='$R_1$', linestyle='-')
plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./onePRE_thinning", bbox_inches='tight')
plt.show()

# %%
XL_twoXLcommon.head()
# Out:
#    Unnamed: 0     x          V      Line1      Line2
# 0           0  0.00   9.931337  49.960584  15.576389
# 1           1  0.01   9.958230  49.951079  34.475926
# 2           2  0.02   9.985000  49.991563  17.683280
# 3           3  0.03  10.011650  49.831974  21.140702
# 4           4  0.04  10.038181  49.889516  37.902967

# %%
plt.figure(figsize=(12,6))
plt.plot(XL_twoXLcommon.x, XL_twoXLcommon.Line1,label='$R_1$', linestyle='-')
plt.plot(XL_twoXLcommon.x, XL_twoXLcommon.Line2,label='$R_2$', linestyle='-')
#plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./TwoXL_common", bbox_inches='tight')
plt.show()

# %%
XL_oneXLcommon.head()
# Out:
#    Unnamed: 0     x         V      Line1  Line2
# 0           0  0.00  9.566705  59.941463    0.0
# 1           1  0.01  9.592244  59.670634    0.0
# 2           2  0.02  9.617665  59.378249    0.0
# 3           3  0.03  9.642969  59.751675    0.0
# 4           4  0.04  9.668158  58.782774    0.0

# %%
plt.figure(figsize=(12,6))
plt.plot(XL_twoXLcommon.x, XL_twoXLcommon.Line1,label='$M$', linestyle='-')
#plt.plot(XL_twoXLcommon.x, XL_twoXLcommon.Line2,label='$R_2$', linestyle='-')
#plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./OneXL_common", bbox_inches='tight')
plt.show()

# %%
P_twoPcommon.head()
# Out:
#    Unnamed: 0     x         V  Line1     Line2
# 0           0  0.00  7.740384    1.0  1.000000
# 1           1  0.01  7.759138    1.0  0.001985
# 2           2  0.02  7.773474    1.0  0.004244
# 3           3  0.03  7.787787    1.0  0.006491
# 4           4  0.04  7.802078    1.0  0.008731

# %%
plt.figure(figsize=(12,6))
plt.plot(P_twoPcommon.x, P_twoPcommon.Line1,label='$b_1$', linestyle='-')
plt.plot(P_twoPcommon.x, P_twoPcommon.Line2,label='$b_2$', linestyle='-')
plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./TwoP_common", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(P_onePcommon.x, P_onePcommon.Line1,label='$b$', linestyle='-')
#plt.plot(P_twoPcommon.x, P_twoPcommon.Line2,label='$R_2$', linestyle='-')
plt.xlim(0,5)
#plt.ylim(0,30)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./OneP_common", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
#plt.plot(XLXLXL.x, XLXLXL.V_XLXLXL,label='XLXLXL Re', linestyle='-')
#plt.plot(XL.x, XL.V_XL,label='XL Re', linestyle='-')
plt.plot(ppp.x, ppp.V_ppp,label='Three proportional reinsurance', linestyle='-')
plt.plot(XLXLXL_edit.x, XLXLXL_edit.V_XLXLXL,label='Three XL reinsurance', linestyle='-')
plt.plot(XL.x, XL.V_XL,label='One XL reinsurance', linestyle='-')

plt.plot(P.x, P.V_ppp,label='one proportional reinsurance', linestyle='-')


plt.xlim(0,10)
plt.ylim(4,9)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multiplevaluefunction", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
#plt.plot(XLXLXL.x, XLXLXL.V_XLXLXL,label='XLXLXL Re', linestyle='-')
#plt.plot(XL.x, XL.V_XL,label='XL Re', linestyle='-')
plt.plot(XL_twoXLcommon.x, XL_twoXLcommon.V,label='Two XL reinsurance', linestyle='-')
plt.plot(XL_oneXLcommon.x, XL_oneXLcommon.V,label='one XL reinsurance ', linestyle='-')
#plt.plot(XLXLXL_edit.x, XLXLXL_edit.V_XLXLXL,label='XLXLXL Reedit', linestyle='-')
#plt.plot(XL.x, XL.V_XL,label='XL Re', linestyle='-')
plt.plot(P_onePcommon.x, P_onePcommon.V,label='one proportional reinsurance ', linestyle='-')
plt.plot(P_twoPcommon.x, P_twoPcommon.V,label='Two proportional reinsurance ', linestyle='-')
#plt.plot(P.x, P.V_ppp,label='One p Re', linestyle='-')


plt.xlim(0,20)
plt.ylim(7,19)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multiplevaluefunction_commonshock", bbox_inches='tight')
plt.show()

# %%
XL.head()
# Out:
#    Unnamed: 0     x      V_XL  XLXLXL_Line1  XLXLXL_Line2  XLXLXL_Line3
# 0           0  0.00  4.520621    118.905447           0.0           0.0
# 1           1  0.05  4.597156    162.105925           0.0           0.0
# 2           2  0.10  4.669541    152.871490           0.0           0.0
# 3           3  0.15  4.738228    168.989848           0.0           0.0
# 4           4  0.20  4.803615    162.828529           0.0           0.0

# %%
PR.head()

# %%
XLXLXL.head()
# Out:
#    Unnamed: 0     x     delta  XLXLXL_Line1  XLXLXL_Line2  XLXLXL_Line3
# 0           0  0.00  0.641954     10.000000  1.000000e+01     10.000000
# 1           1  0.01  0.646972      0.009995 -3.473937e-09      9.999820
# 2           2  0.02  0.649831      0.009994  1.999999e-02      9.999936
# 3           3  0.03  0.652671      0.009999  2.999938e-02      9.999208
# 4           4  0.04  0.655505      0.009996  3.999999e-02      9.999880

# %%
plt.figure(figsize=(12,6))
plt.plot(XLXLXL.x, XLXLXL.XLXLXL_Line1,label='$M_1$')
plt.plot(XLXLXL.x, XLXLXL.XLXLXL_Line2,label='$M_2$')
plt.plot(XLXLXL.x, XLXLXL.XLXLXL_Line3,label='$M_3$')
plt.xlim(0,6)
plt.ylim(0,1.1)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLXLXL_Re" , bbox_inches='tight')
plt.show()

# %%
XLXLp.head()
# Out:
#    Unnamed: 0     x     delta  XLXLp_Line1  XLXLp_Line2  pXLp_Line3
# 0           0  0.00  0.447364    10.000000    10.000000    1.000000
# 1           1  0.01  0.450825     0.009639     9.997949    0.999994
# 2           2  0.02  0.452932    10.000000    10.000000    1.000000
# 3           3  0.03  0.456405    10.000000    10.000000    1.000000
# 4           4  0.04  0.459889    10.000000    10.000000    1.000000

# %%
plt.figure(figsize=(12,6))
plt.plot(XLXLp.x, XLXLp.XLXLp_Line1,label='$M_1$')
plt.plot(XLXLp.x, XLXLp.XLXLp_Line2,label='$M_2$')
plt.plot(XLXLp.x, XLXLp.pXLp_Line3,label='$b_3$')
plt.xlim(0,6)
plt.ylim(0.0,1.1)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLXLp_Re" , bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(pXLXL.x, pXLXL.pXLXL_Line1,label='$b_1$')
plt.plot(pXLXL.x, pXLXL.pXLXL_Line2,label='$M_2$')
plt.plot(pXLXL.x, pXLXL.pXLXL_Line3,label='$M_3$')
plt.xlim(0.0,6)
plt.ylim(0,1.2)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./pXLXL_Re" , bbox_inches='tight')
plt.show()

# %%
pXLXL.head()
# Out:
#    Unnamed: 0     x     delta  pXLXL_Line1  pXLXL_Line2  pXLXL_Line3
# 0           0  0.00  0.545043     1.000000    10.000000    10.000000
# 1           1  0.01  0.547361     1.000000    10.000000    10.000000
# 2           2  0.02  0.549681     0.999998     0.019999     0.019957
# 3           3  0.03  0.551846     1.000000    10.000000    10.000000
# 4           4  0.04  0.554167     1.000000     0.040000     9.999150

# %%
plt.figure(figsize=(12,6))
plt.plot(pXLp.x, pXLp.pXLp_Line1,label='$b_1$')
plt.plot(pXLp.x, pXLp.pXLp_Line2,label='$M_2$')
plt.plot(pXLp.x, pXLp.pXLp_Line3,label='$b_3$')
plt.xlim(-0.1,20)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./pXLp_Re" , bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(ppp.x, ppp.ppp_Line1,label='$b_1$')
plt.plot(ppp.x, ppp.ppp_Line2,label='$b_2$')
plt.plot(ppp.x, ppp.ppp_Line3,label='$b_3$')
plt.xlim(0,20)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./ppp_Re" , bbox_inches='tight')
plt.show()

# %%
ppp.head()
# Out:
#    Unnamed: 0     x     delta  ppp_Line1  ppp_Line2  ppp_Line3
# 0           0  0.00  0.299600        1.0   1.000000        1.0
# 1           1  0.05  0.305869        1.0   0.001299        1.0
# 2           2  0.10  0.311854        1.0   0.000000        1.0
# 3           3  0.15  0.317760        1.0   0.000000        1.0
# 4           4  0.20  0.323624        1.0   0.009391        1.0

# %%
plt.figure(figsize=(12,6))
plt.plot(XLpXL.x, XLpXL.XLpXL_Line1,label='$M_1$')
plt.plot(XLpXL.x, XLpXL.XLpXL_Line2,label='$b_2$')
plt.plot(XLpXL.x, XLpXL.XLpXL_Line3,label='$M_3$')
plt.xlim(0.0,10)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLpXL_Re" , bbox_inches='tight')
plt.show()

# %% [markdown]
# # XLpXL.head()

# %%
plt.figure(figsize=(12,6))
plt.plot(XLXLp.x, XLXLp.XLXLp_Line1,label='$M_1$')
plt.plot(XLXLp.x, XLXLp.XLXLp_Line2,label='$M_2$')
plt.plot(XLXLp.x, XLXLp.pXLp_Line3,label='$b_3$')
plt.xlim(0.0,10)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLXLp_Re" , bbox_inches='tight')
plt.show()

# %%
XLXLp.head()
# Out:
#    Unnamed: 0     x     delta  XLXLp_Line1  XLXLp_Line2  pXLp_Line3
# 0           0  0.00  0.447364    10.000000    10.000000    1.000000
# 1           1  0.01  0.450825     0.009639     9.997949    0.999994
# 2           2  0.02  0.452932    10.000000    10.000000    1.000000
# 3           3  0.03  0.456405    10.000000    10.000000    1.000000
# 4           4  0.04  0.459889    10.000000    10.000000    1.000000

# %%
plt.figure(figsize=(12,6))
plt.plot(ppXL.x, ppXL.ppXL_Line1,label='$b_1$')
plt.plot(ppXL.x, ppXL.ppXL_Line2,label='$b_2$')
plt.plot(ppXL.x, ppXL.ppXL_Line3,label='$M_3$')
plt.xlim(0.0,10)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./ppXL_Re" , bbox_inches='tight')
plt.show()

# %%
ppXL.head()
# Out:
#    Unnamed: 0         x     delta  ppXL_Line1  ppXL_Line2  ppXL_Line3
# 0           0  0.000000  0.464510    1.000000    1.000000   10.000000
# 1           1  0.033333  0.473793    0.004023    0.999999    0.033332
# 2           2  0.066667  0.480561    0.008571    0.999978    0.066666
# 3           3  0.100000  0.487097    0.013099    0.999996    0.100000
# 4           4  0.133333  0.493491    0.017615    1.000000    0.100000

# %%
XLpp.head()
# Out:
#    Unnamed: 0     x     delta  XLpp_Line1  XLpp_Line2  XLpp_Line3
# 0           0  0.00  0.300012   10.000000    1.000000    1.000000
# 1           1  0.01  0.302288    0.009905    0.999983    0.999999
# 2           2  0.02  0.303664   10.000000    1.000000    1.000000
# 3           3  0.03  0.305938    0.010000    0.000647    0.999988
# 4           4  0.04  0.307251    0.010000    0.999908    0.999992

# %%
plt.figure(figsize=(12,6))
plt.plot(XLpp.x, XLpp.XLpp_Line1,label='$M_1$')
plt.plot(XLpp.x, XLpp.XLpp_Line2,label='$b_2$')
plt.plot(XLpp.x, XLpp.XLpp_Line3,label='$b_3$')
plt.xlim(0.0,20)
plt.ylim(0,1.32)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$Reinsurance$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLpp_Re" , bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(ppp.x, ppp.delta,label='p,p,p',linestyle='dashdot')
plt.plot(ppXL.x, ppXL.delta,label='p,p,XL',linestyle='dashdot')
plt.plot(pXLp.x, pXLp.delta,label='p,XL,p')
plt.plot(XLpp.x, XLpp.delta,label='XL,p,p')
plt.plot(pXLXL.x, pXLXL.delta,label='p,XL,XL')
plt.plot(XLpXL.x, XLpXL.delta,label='XL,p,XL')
plt.plot(XLXLp.x, XLXLp.delta,label='XL,XL,p')
plt.plot(XLXLXL.x, XLXLXL.delta,label='XL,XL,XL')
plt.xlim(0,6)
plt.ylim(0.27,1)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multipleSurvival2", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
#plt.plot(ppp.x, ppp.delta,label='p,p,p', linestyle='-')
plt.plot(ppXL.x, ppXL.delta,label='p,p,XL', linestyle='-')
plt.plot(pXLp.x, pXLp.delta,label='p,XL,p', linestyle='dashdot')
plt.plot(XLpp.x, XLpp.delta,label='XL,p,p')
#plt.plot(pXLXL.x, pXLXL.delta,label='p,XL,XL', linestyle='dashed')
#plt.plot(XLpXL.x, XLpXL.delta,label='XL,p,XL', linestyle='-')
#plt.plot(XLXLp.x, XLXLp.delta,label='XL,XL,p', linestyle='dashdot')
#plt.plot(XLXLXL.x, XLXLXL.delta,label='XL,XL,XL', linestyle='dashdot')
plt.xlim(0,15)
plt.ylim(0.27,1)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multipleSurvival22", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
#plt.plot(ppp.x, ppp.delta,label='p,p,p', linestyle='-')
#plt.plot(ppXL.x, ppXL.delta,label='p,p,XL', linestyle='-')
#plt.plot(pXLp.x, pXLp.delta,label='p,XL,p', linestyle='dashdot')
#plt.plot(XLpp.x, XLpp.delta,label='XL,p,p')
plt.plot(pXLXL.x, pXLXL.delta,label='p,XL,XL', linestyle='dashed')
plt.plot(XLpXL.x, XLpXL.delta,label='XL,p,XL', linestyle='-')
plt.plot(XLXLp.x, XLXLp.delta,label='XL,XL,p', linestyle='dashdot')
#plt.plot(XLXLXL.x, XLXLXL.delta,label='XL,XL,XL', linestyle='dashdot')
plt.xlim(0,6)
plt.ylim(0.27,1)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./multipleSurvival23", bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
#plt.plot(ppp.x, ppp.delta,label='p,p,p', linestyle='-')
#plt.plot(ppXL.x, ppXL.delta,label='p,p,XL', linestyle='-')
#plt.plot(pXLp.x, pXLp.delta,label='p,XL,p', linestyle='dashdot')
#plt.plot(XLpp.x, XLpp.delta,label='XL,p,p')
#plt.plot(pXLXL.x, pXLXL.delta,label='p,XL,XL', linestyle='dashed')
#plt.plot(XLpXL.x, XLpXL.delta,label='XL,p,XL', linestyle='-')
plt.plot(XLXLXL.x, XLXLXL.XLXLXL_Line1,label='$\Delta=0.01$')
plt.plot(XLXLXL1.x, XLXLXL1.XLXLXL_Line1,label='$\Delta=0.0004$')
plt.xlim(0,0.1)
plt.ylim(0.0,0.02)
plt.xlabel('$x$', fontsize=20)
plt.ylabel(r'$\delta(x)$', fontsize=20)
plt.axhline(y=0, color='k');plt.axvline(x=0, color='k')
plt.grid( color='0.7', linestyle='--')
plt.legend()
plt.savefig("./XLdelta", bbox_inches='tight')
plt.show()

# %%
XLXLXL.head()
# Out:
#    Unnamed: 0     x     delta  XLXLXL_Line1  XLXLXL_Line2  XLXLXL_Line3
# 0           0  0.00  0.641954     10.000000  1.000000e+01     10.000000
# 1           1  0.01  0.646972      0.009995 -3.473937e-09      9.999820
# 2           2  0.02  0.649831      0.009994  1.999999e-02      9.999936
# 3           3  0.03  0.652671      0.009999  2.999938e-02      9.999208
# 4           4  0.04  0.655505      0.009996  3.999999e-02      9.999880
